# %% [markdown]
# <a href="https://colab.research.google.com/github/GianK19/MetNumUN2023II/blob/main/glanziano_Lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# **My last digit ID: 3**

# %% [markdown]
# **My own polynomial degree 10**

# %% [markdown]
# ![Wolfram1.png](data:image/png;base64,...)

# %% [markdown]
# **My own polynomial divided by a root**

# %% [markdown]
# ![Wolfram2.1.png](data:image/png;base64,...)
#
# ![Wolfram2.2.png](data:image/png;base64,...)

# %% [markdown]
# **My polynomial divided by a NON root**

# %% [markdown]
# ![Wolfram3.1.png](data:image/png;base64,...)
# ![Wolfram3.2.png](data:image/png;base64,...)

# %% [markdown]
# **Sympy divide my polynomial by all 10 roots**

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**10 - 381*x**9 + 61732*x**8 - 5576810*x**7 + 309455917*x**6 - 10948213109*x**5 + 247945904598*x**4 - 3507216287300*x**3 + 29101365681432*x**2 - 123395673250080*x + 185332571424000

p, r = div(p,  x-50)
print("Primera Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-15)
print("Segunda Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-26)
print("Tercera Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-21)
print("Cuarta Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-44)
print("Quinta Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-88)
print("Sexta Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-11)
print("Septima Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-46)
print("Octava Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-77)
print("Novena Raiz")
print("Resultado: ", p)
print("Residuo: ", r)

p, r = div(p,  x-3)
print("Decima Raiz")
print("Resultado: ", p)
print("Residuo: ", r)
# Out:
# Primera Raiz
# Resultado:  x**9 - 331*x**8 + 45182*x**7 - 3317710*x**6 + 143570417*x**5 - 3769692259*x**4 + 59461291648*x**3 - 534151704900*x**2 + 2393780436432*x - 3706651428480
# Residuo:  0
# Segunda Raiz
# Resultado:  x**8 - 316*x**7 + 40442*x**6 - 2711080*x**5 + 102904217*x**4 - 2226129004*x**3 + 26069356588*x**2 - 143111356080*x + 247110095232
# Residuo:  0
# Tercera Raiz
# Resultado:  x**7 - 290*x**6 + 32902*x**5 - 1855628*x**4 + 54657889*x**3 - 805023890*x**2 + 5138735448*x - 9504234432
# Residuo:  0
# Cuarta Raiz
# Resultado:  x**6 - 269*x**5 + 27253*x**4 - 1283315*x**3 + 27708274*x**2 - 223150136*x + 452582592
# Residuo:  0
# Quinta Raiz
# Resultado:  x**5 - 225*x**4 + 17353*x**3 - 519783*x**2 + 4837822*x - 10285968
# Residuo:  0
# Sexta Raiz
# Resultado:  x**4 - 137*x**3 + 5297*x**2 - 53647*x + 116886
# Residuo:  0
# Septima Raiz
# Resultado:  x**3 - 126*x**2 + 3911*x - 10626
# Residuo:  0
# Octava Raiz
# Resultado:  x**2 - 80*x + 231
# Residuo:  0
# Novena Raiz
# ...

# %% [markdown]
# **Sympy divides my polynomial by a NO root**

# %%
p = x**10 - 381*x**9 + 61732*x**8 - 5576810*x**7 + 309455917*x**6 - 10948213109*x**5 + 247945904598*x**4 - 3507216287300*x**3 + 29101365681432*x**2 - 123395673250080*x + 185332571424000

p, r = div(p,  x-55)
print("No es Raiz x-55")
print("Resultado: ", p)
print("Residuo: ", r)
# Out:
# No es Raiz x-55
# Resultado:  x**9 - 326*x**8 + 43802*x**7 - 3167700*x**6 + 135232417*x**5 - 3510430174*x**4 + 54872245028*x**3 - 489242810760*x**2 + 2193011089632*x - 2780063320320
# Residuo:  32429088806400

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(x\*\*10 - 381\*x\*\*9 + 61732\*x\*\*8 - 5576810\*x\*\*7 + 309455917\*x\*\*6 - 10948213109\*x\*\*5 + 247945904598\*x\*\*4 - 3507216287300\*x\*\*3 + 29101365681432\*x\*\*2 - 123395673250080\*x + 185332571424000)

# %% [markdown]
# ![Wolfram4.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 381*x**9 + 61732*x**8 - 5576810*x**7 + 309455917*x**6 - 10948213109*x**5 + 247945904598*x**4 - 3507216287300*x**3 + 29101365681432*x**2 - 123395673250080*x + 185332571424000)
# Out:
# (x - 88)*(x - 77)*(x - 50)*(x - 46)*(x - 44)*(x - 26)*(x - 21)*(x - 15)*(x - 11)*(x - 3)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# - x\*\*10 - 381\*x\*\*9 + 61732\*x\*\*8 - 5576810\*x\*\*7 + 309455917\*x\*\*6 - 10948213109\*x\*\*5 + 247945904598\*x\*\*4 - 3507216287300\*x\*\*3 + 29101365681432\*x\*\*2 - 123395673250080\*x + 185332571424000 = 0

# %% [markdown]
# ![Wolfram5.png](data:image/png;base64,...)![Wolfram5.1.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**10 - 381*x**9 + 61732*x**8 - 5576810*x**7 + 309455917*x**6 - 10948213109*x**5 + 247945904598*x**4 - 3507216287300*x**3 + 29101365681432*x**2 - 123395673250080*x + 185332571424000, 0), x)
# Out:
# {3, 11, 15, 21, 26, 44, 46, 50, 77, 88}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, E
x = Symbol('x')
solveset(Eq(x**2*pi-(pi+sqrt(7))+(sqrt(23)+pi) , 0), x)
# Out:
# {-sqrt(-sqrt(23) + sqrt(7))/sqrt(pi), sqrt(-sqrt(23) + sqrt(7))/sqrt(pi)}

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**10 - 381*x**9 + 61732*x**8 - 5576810*x**7 + 309455917*x**6 - 10948213109*x**5 + 247945904598*x**4 - 3507216287300*x**3 + 29101365681432*x**2 - 123395673250080*x + 185332571424000,domain='GF(3)')
# Out:
# x**3*(x - 1)**2*(x + 1)**5

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import symbols, I, N, pi, expand
x1, y1, z1 = symbols("x1 y1 z1 ", real=True)
x = 32 + I*x1
y = 34 + I*y1
z = 39 + I*z1

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))


w = N(1/(pi + I), 20)
print('w =',w)
# Out:
# (I*x1 + 32)*(I*y1 + 34)*(I*z1 + 39)
# -I*x1*y1*z1 - 39*x1*y1 - 34*x1*z1 + 1326*I*x1 - 32*y1*z1 + 1248*I*y1 + 1088*I*z1 + 42432
# -I*x1*y1*z1 - 39*x1*y1 - 34*x1*z1 + 1326*I*x1 - 32*y1*z1 + 1248*I*y1 + 1088*I*z1 + 42432
# -I*x1*y1*z1 - 39*x1*y1 - 34*x1*z1 + 1326*I*x1 - 32*y1*z1 + 1248*I*y1 + 1088*I*z1 + 42432
# w = 0.28902548222223624241 - 0.091999668350375232456*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average temperature in Bogota in September?
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Try the same question asked in Wolfram Alpha in ChatGPT**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate
#
# My own integral
#
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
from math import e
x = Symbol('x')
integrate(e**(-x)*sin(x), x)
# Out:
# -0.5*sin(x)/2.71828182845905**x - 0.5*cos(x)/2.71828182845905**x

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin, cos, ln
from math import e
x = Symbol('x')
integrate(e**(cos(x))*sin(x)+ln(x**2 + 2*x + 2), (x,e,100))
# Out:
# -206.803566572364 - 1.0*2.71828182845905**cos(100) + 2*atan(101) + 101*log(10202)

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(e**(cos(x))*sin(x)+ln(x**2 + 2*x + 2), (x,e,100)))
# Out:
# 726.213822734799
